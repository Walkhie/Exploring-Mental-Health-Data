# %% [markdown]
# <a href="https://colab.research.google.com/github/Walkhie/Exploring-Mental-Health-Data/blob/main/3_1)Despliegue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías básicas
import pandas as pd # manipulacion dataframes
import numpy as np  # matrices y vectores
import matplotlib.pyplot as plt #gráfica

# %%
#Cargamos el modelo
import pickle
# Importar las dependencias del Pipe
from AjustarData import Imputacion, TransformarSueño, TransformarDieta, ReduccionCategorias
from AjustarData import eliminar_variables_irrelevantes,eliminar_outliers

# Cargar el Pipe
filename = 'pipeline_modelo.pkl'
pipeline = pickle.load(open(filename, 'rb'))
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('imputacion', Imputacion()),
#                                  ('Categorizar Sueño', TransformarSueño()),
#                                  ('Categorizar Dieta', TransformarDieta()),
#                                  ('Reduccion de categorias',
#                                   ReduccionCategorias()),
#                                  ('eliminar variables irrelevantes',
#                                   FunctionTransformer(func=<function eliminar_variables_irrelevantes at 0x781100adb6d0>)),
#                                  ('outliers',
#                                   FunctionTransfor...
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('dummies',
# ...

# %%
#Cargamos los datos futuros
test = pd.read_csv("test.csv")
test.head()
# Out:
#        id     Name  Gender   Age           City  \
# 0  140700   Shivam    Male  53.0  Visakhapatnam
# 1  140701    Sanya  Female  58.0        Kolkata
# 2  140702     Yash    Male  53.0         Jaipur
# 3  140703   Nalini  Female  23.0         Rajkot
# 4  140704  Shaurya    Male  47.0         Kalyan
#
#   Working Professional or Student              Profession  Academic Pressure  \
# 0            Working Professional                   Judge                NaN
# 1            Working Professional  Educational Consultant                NaN
# 2            Working Professional                 Teacher                NaN
# 3                         Student                     NaN                5.0
# 4            Working Professional                 Teacher                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            2.0   NaN                 NaN               5.0
# 1            2.0   NaN                 NaN               4.0
# ...

# %%
pred = pipeline.predict(test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
test['Prediction'] = pred
test
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student Profession  Academic Pressure  \
# 0                Working Professional      Other               -1.0
# 1                Working Professional      Other               -1.0
# 2                Working Professional    Teacher               -1.0
# ...

# %%
entregable = test[['id','Prediction']]
entregable
# Out:
#            id  Prediction
# 0      140700           0
# 1      140701           0
# 2      140702           0
# 3      140703           1
# 4      140704           0
# ...       ...         ...
# 93795  234495           0
# 93796  234496           1
# 93797  234497           0
# 93798  234498           1
# 93799  234499           0
#
# [93800 rows x 2 columns]

# %%
entregable.to_csv('entregable.csv', index=False)
