# %% [markdown]
# <a href="https://colab.research.google.com/github/Walkhie/Exploring-Mental-Health-Data/blob/main/3_2)Despliegue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías básicas
import pandas as pd # manipulacion dataframes
import numpy as np  # matrices y vectores
import matplotlib.pyplot as plt #gráfica

# %%
#Cargamos el modelo
import pickle
# Importar las dependencias del Pipe
from AjustarData import Imputacion, TransformarSueño, TransformarDieta, ReduccionCategorias
from AjustarData import eliminar_variables_irrelevantes,eliminar_outliers

# Cargar el Pipe
filename = 'pipeline_modelo.pkl'
pipeline = pickle.load(open(filename, 'rb'))
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('imputacion', Imputacion()),
#                                  ('Categorizar Sueño', TransformarSueño()),
#                                  ('Categorizar Dieta', TransformarDieta()),
#                                  ('Reduccion de categorias',
#                                   ReduccionCategorias()),
#                                  ('eliminar variables irrelevantes',
#                                   FunctionTransformer(func=<function eliminar_variables_irrelevantes at 0x79d3a8654700>)),
#                                  ('outliers',
#                                   FunctionTransfor...
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('dummies',
#                                                                                     OneHotEncoder(drop='if_binary',
#                                                                                                   handle_unknown='ignore',
#                                                                                                   sparse_output=False))]),
#                                                                    ['Dietary '
#                                                                     'Habits',
#                                                                     'Have you '
#                                                                     'ever had '
#                                                                     'suicidal '
#                                                                     'thoughts '
#                                                                     '?',
#                                                                     'Profession',
#                                                                     'Degree'])]))])),
#                 ('model',
#                  GradientBoostingClassifier(criterion='squared_error',
#                                             learning_rate=0.08404433875110165,
#                                             max_depth=5, min_samples_leaf=2,
#                                             n_estimators=194, subsample=0.8))])

# %%
#Se crea interfaz gráfica con streamlit para captura de los datos

import streamlit as st

st.title('Predicción de Depresión')

# Variables no necesarias
id = 1
Name = ''
Gender =''
City = ''
Work_Student = ''
Work_Pressure = 1
CGPA = 1
Study_Satisfaction = 1
Job_Satisfaction = 1
Sleep_Duration = ''
Family = ''


# Variables necesarias
Age = st.slider('Edad', min_value=10, max_value=80, value=30, step=1)
Academic_Pressure = st.selectbox('Academic Pressure (Elija -1 sino aplica)', [-1,1,2,3,4,5])
Work_Study_Hours = st.slider('Work/Study Hours', min_value=0, max_value=45, value=0, step=1)
Financial_Stress = st.selectbox('Financial Stress (Elija -1 sino aplica)', [-1,1,2,3,4,5])
Dietary_habits = st.selectbox('Dietary Habits', ['Healthy', 'Unhealthy', 'Moderate'])
Suicidal_Thoughts = st.selectbox('Have you ever had suicidal thoughts ?', ['Yes', 'No'])
Profession = st.selectbox('Profession', ['Other', 'Teacher', 'Student','Content Writer'])
Degree = st.selectbox('Degree', ['Other', 'Class 12', 'B.Ed','B.Arch','B.Com','B.Pharm', 'BCA', 'M.Ed', 'MCA', 'BBA', 'BSc'])





datos = [[ id, Name, Gender,City,Work_Pressure ,Work_Student,CGPA, Study_Satisfaction,Job_Satisfaction , Sleep_Duration,Age,Academic_Pressure,Work_Study_Hours,Financial_Stress,Dietary_habits, Suicidal_Thoughts, Profession, Degree, Family]]
data = pd.DataFrame(datos, columns=['id','Name','Gender','City','Work Pressure','Working Professional or Student','CGPA','Study Satisfaction','Job Satisfaction','Sleep Duration','Age', 'Academic Pressure','Work/Study Hours', 'Financial Stress', 'Dietary Habits','Have you ever had suicidal thoughts ?','Profession','Degree', 'Family History of Mental Illness' ]) #Dataframe con los mismos nombres de variables
# Out:
# 2024-11-13 14:10:40.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 14:10:40.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
y_pred = pipeline.predict(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
data = data.drop(columns=['id','Name','Gender','City','Work Pressure','Working Professional or Student','CGPA','Study Satisfaction','Job Satisfaction','Sleep Duration'])
data['Prediction'] = y_pred
data
